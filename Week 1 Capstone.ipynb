# %% [markdown]
# # The Battle of the Neighborhoods

# %% [markdown]
# Introduction:

# %% [markdown]
# One of the most diverse cities in the United States is New York City. New York City is the largest city in the United States with a long history of international immigration.  Restaurants are a place where people from all cultures can come together. In this project, I will find the "best" area to open a new indian restaurant. The criteras will be a low risk criteria and high success rate. We will need to take into account population in neighborhood, competitors, and places near the location such as entertainment establishments

# %% [markdown]
# Data:

# %% [markdown]
# One of the data that will be used in this capstone is New York City data that contains Borough, Neighborhoods along with the latitudes and longitudes. The data source for thsi will be https://cocl.us/new_york_dataset. Another data that will be used is Indian restaurants in the neighborhoods of new york city. For this, the data source will be Foursquare API. The Foursquare API will provide us with all the venues in the new york city neighborhoods.
